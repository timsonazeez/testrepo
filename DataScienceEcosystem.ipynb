# %% [markdown]
# # Data Science Tools and Ecosysyem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objective**
# - List popular languages for Data Science
# - List few of the Data Science libraries
# - List Data Science environment
# - Engage in simple arithmetic

# %% [markdown]
# some of the popular languages that data Scientsits use are:
# 1. Python
# 2. R
# 3. Julia
# 4. C++

# %% [markdown]
# some of the commonly used libraries by Data Scientists include:
# 1. Numpy
# 2. Panda
# 3. Scikitlearn
# 4. Seaborn

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyther Notebook|
# |Jupyther Lite|
# |VS Code|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in python

# %%
# This is simple adding and multiplication of numbers.
(2*4)+5
# Out:
# 13

# %%
#This will convert minutes to hour by dividing by 60.
h = 60
y = 200
y/h
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author's Name

# %% [markdown]
# Azeez Timson
